# %% [markdown]
# <img src="https://github.com/hernancontigiani/ceia_memorias_especializacion/raw/master/Figures/logoFIUBA.jpg" width="500" align="center">
#
#
# # Procesamiento de lenguaje natural
# ## Modelo de lenguaje con tokenización por caracteres

# %% [markdown]
# ### Consigna
# - Seleccionar un corpus de texto sobre el cual entrenar el modelo de lenguaje.
# - Realizar el pre-procesamiento adecuado para tokenizar el corpus, estructurar el dataset y separar entre datos de entrenamiento y validación.
# - Proponer arquitecturas de redes neuronales basadas en unidades recurrentes para implementar un modelo de lenguaje.
# - Con el o los modelos que consideren adecuados, generar nuevas secuencias a partir de secuencias de contexto con las estrategias de greedy search y beam search determístico y estocástico. En este último caso observar el efecto de la temperatura en la generación de secuencias.
#
#
# ### Sugerencias
# - Durante el entrenamiento, guiarse por el descenso de la perplejidad en los datos de validación para finalizar el entrenamiento. Para ello se provee un callback.
# - Explorar utilizar SimpleRNN (celda de Elman), LSTM y GRU.
# - rmsprop es el optimizador recomendado para la buena convergencia. No obstante se pueden explorar otros.

# %%
import random
import io
import pickle
from cProfile import label

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras import layers
from keras.utils import to_categorical
from keras.models import Sequential
from keras.layers import Dense, LSTM, Embedding, Dropout
from tensorflow.keras.losses import SparseCategoricalCrossentropy
# Out:
# 2025-04-27 15:05:30.542449: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-27 15:05:30.553187: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745777130.563995   31683 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745777130.567154   31683 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745777130.576961   31683 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745777130.576979   31683 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745777130.576980   31683 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1745777130.576982   31683 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-04-27 15:05:30.581456: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### Datos
# Utilizaremos como dataset uno disponible en kaggle sobre papers relacionados a AI. Contiene tags y abstracts (parrafo resumen). Voy a utilizar los primeros 10000 titulos + abstracts compilados en un unico texto.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("sumitm004/arxiv-scientific-research-papers-dataset")

print("Path to dataset files:", path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.8), please consider upgrading to the latest version (0.3.12).
# Path to dataset files: /home/juan/.cache/kagglehub/datasets/sumitm004/arxiv-scientific-research-papers-dataset/versions/2

# %%
# With the dataset loaded, we can now read the csv into a pandas dataframe     
df = pd.read_csv(path + '/arXiv_scientific dataset.csv')

# %%
df
# Out:
#                       id                                              title  \
# 0           cs-9308101v1                               Dynamic Backtracking
# 1           cs-9308102v1  A Market-Oriented Programming Environment and ...
# 2           cs-9309101v1            An Empirical Analysis of Search in GSAT
# 3           cs-9311101v1  The Difficulties of Learning Logic Programs wi...
# 4           cs-9311102v1  Software Agents: Completing Patterns and Const...
# ...                  ...                                                ...
# 136233  abs-2408.08541v1         Where is the signal in tokenization space?
# 136234  abs-2408.08564v1  Collaborative Cross-modal Fusion with Large La...
# 136235  abs-2408.08624v1  RealMedQA: A pilot biomedical question answeri...
# 136236  abs-2408.08648v1  Understanding Enthymemes in Argument Maps: Bri...
# 136237  abs-2408.08651v2  Reasoning Beyond Bias: A Study on Counterfactu...
#
#                                                  category category_code  \
# 0                                 Artificial Intelligence         cs.AI
# 1                                 Artificial Intelligence         cs.AI
# 2                                 Artificial Intelligence         cs.AI
# 3                                 Artificial Intelligence         cs.AI
# 4                                 Artificial Intelligence         cs.AI
# ...                                                   ...           ...
# 136233  Computation and Language (Natural Language Pro...         cs.CL
# 136234                              Information Retrieval         cs.IR
# 136235  Computation and Language (Natural Language Pro...         cs.CL
# 136236                            Artificial Intelligence         cs.AI
# 136237  Computation and Language (Natural Language Pro...         cs.CL
#
#        published_date updated_date  \
# 0              8/1/93       8/1/93
# 1              8/1/93       8/1/93
# 2              9/1/93       9/1/93
# 3             11/1/93      11/1/93
# 4             11/1/93      11/1/93
# ...               ...          ...
# 136233        8/16/24      8/16/24
# 136234        8/16/24      8/16/24
# 136235        8/16/24      8/16/24
# 136236        8/16/24      8/16/24
# 136237        8/16/24       9/6/24
#
#                                                   authors  \
# 0                                      ['M. L. Ginsberg']
# 1                                       ['M. P. Wellman']
# 2                              ['I. P. Gent', 'T. Walsh']
# 3          ['F. Bergadano', 'D. Gunetti', 'U. Trinchero']
# 4                    ['J. C. Schlimmer', 'L. A. Hermens']
# ...                                                   ...
# 136233  ['Renato Lui Geh', 'Honghua Zhang', 'Kareem Ah...
# 136234  ['Zhongzhou Liu', 'Hao Zhang', 'Kuicai Dong', ...
# 136235  ['Gregory Kell', 'Angus Roberts', 'Serge Umans...
# 136236  ['Jonathan Ben-Naim', 'Victor David', 'Anthony...
# 136237  ['Kyle Moore', 'Jesse Roberts', 'Thao Pham', '...
#
#                first_author  \
# 0          'M. L. Ginsberg'
# 1           'M. P. Wellman'
# 2              'I. P. Gent'
# 3            'F. Bergadano'
# 4         'J. C. Schlimmer'
# ...                     ...
# 136233     'Renato Lui Geh'
# 136234      'Zhongzhou Liu'
# 136235       'Gregory Kell'
# 136236  'Jonathan Ben-Naim'
# 136237         'Kyle Moore'
#
#                                                   summary  summary_word_count
# 0       Because of their occasional need to return to ...                  79
# 1       Market price systems constitute a well-underst...                 119
# 2       We describe an extensive study of search in GS...                 167
# 3       As real logic programmers normally use cut (!)...                 174
# 4       To support the goal of allowing users to recor...                 187
# ...                                                   ...                 ...
# 136233  Large Language Models (LLMs) are typically shi...                 170
# 136234  Despite the success of conventional collaborat...                 157
# 136235  Clinical question answering systems have the p...                 153
# 136236  Argument mining is natural language processing...                 194
# 136237  Language models are known to absorb biases fro...                 156
#
# [136238 rows x 10 columns]

# %%
# we build a 'book' concatenating the titles followed by \n followed by the summary of the papers followed by \n and next title and so on 
# first we choose 100 random papers from the dataset    
df = df.sample(100)  
article_text = ''
for index, row in df.iterrows():
    article_text += row['title'] + ' \n' + row['summary'] + ' \n'

# %%
# pasar todo el texto a minúscula
article_text = article_text.lower()

# %%
article_text[:1000]
# Out:
# 'a lightweight reconstruction network for surface defect inspection \ncurrently, most deep learning methods cannot solve the problem of scarcity of\nindustrial product defect samples and significant differences in\ncharacteristics. this paper proposes an unsupervised defect detection algorithm\nbased on a reconstruction network, which is realized using only a large number\nof easily obtained defect-free sample data. the network includes two parts:\nimage reconstruction and surface defect area detection. the reconstruction\nnetwork is designed through a fully convolutional autoencoder with a\nlightweight structure. only a small number of normal samples are used for\ntraining so that the reconstruction network can be a defect-free reconstructed\nimage is generated. a function combining structural loss and $\\mathit{l}1$ loss\nis proposed as the loss function of the reconstruction network to solve the\nproblem of poor detection of irregular texture surface defects. further, the\nresidual of the reconstr'

# %% [markdown]
# ### Elegir el tamaño del contexto
#
# En este caso, como el modelo de lenguaje es por caracteres, todo un gran corpus
# de texto puede ser considerado un documento en sí mismo y el tamaño de contexto
# puede ser elegido con más libertad en comparación a un modelo de lenguaje tokenizado por palabras y dividido en documentos más acotados.

# %%
# seleccionamos el tamaño de contexto
max_context_size = 100

# %%
# Usaremos las utilidades de procesamiento de textos y secuencias de Keras
from tensorflow.keras.utils import pad_sequences # se utilizará para padding

# %%
# en este caso el vocabulario es el conjunto único de caracteres que existe en todo el texto
chars_vocab = set(article_text)

# %%
# la longitud de vocabulario de caracteres es:
len(chars_vocab)
# Out:
# 65

# %%
# Construimos los dicionarios que asignan índices a caracteres y viceversa.
# El diccionario `char2idx` servirá como tokenizador.
char2idx = {k: v for v,k in enumerate(chars_vocab)}
idx2char = {v: k for k,v in char2idx.items()}

# %% [markdown]
# ###  Tokenizar

# %%
# tokenizamos el texto completo
tokenized_text = [char2idx[ch] for ch in article_text]

# %%
tokenized_text[:1000]
# Out:
# [37,
#  49,
#  26,
#  2,
#  64,
#  10,
#  55,
#  17,
#  16,
#  2,
#  64,
#  10,
#  55,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  49,
#  19,
#  6,
#  38,
#  49,
#  3,
#  34,
#  38,
#  19,
#  37,
#  62,
#  16,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  49,
#  2,
#  45,
#  3,
#  50,
#  16,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  36,
#  62,
#  34,
#  38,
#  38,
#  16,
#  45,
#  55,
#  26,
#  9,
#  18,
#  49,
#  43,
#  6,
#  3,
#  55,
#  49,
#  52,
#  16,
#  16,
#  50,
#  49,
#  26,
#  16,
#  37,
#  38,
#  45,
#  2,
#  45,
#  64,
#  49,
#  43,
#  16,
#  55,
#  10,
#  6,
#  52,
#  3,
#  49,
#  62,
#  37,
#  45,
#  45,
#  6,
#  55,
#  49,
#  3,
#  6,
#  26,
#  14,
#  16,
#  49,
#  55,
#  10,
#  16,
#  49,
#  50,
#  38,
#  6,
#  20,
#  26,
#  16,
#  43,
#  49,
#  6,
#  19,
#  49,
#  3,
#  62,
#  37,
#  38,
#  62,
#  2,
#  55,
#  9,
#  49,
#  6,
#  19,
#  36,
#  2,
#  45,
#  52,
#  34,
#  3,
#  55,
#  38,
#  2,
#  37,
#  26,
#  49,
#  50,
#  38,
#  6,
#  52,
#  34,
#  62,
#  55,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  49,
#  3,
#  37,
#  43,
#  50,
#  26,
#  16,
#  3,
#  49,
#  37,
#  45,
#  52,
#  49,
#  3,
#  2,
#  64,
#  45,
#  2,
#  19,
#  2,
#  62,
#  37,
#  45,
#  55,
#  49,
#  52,
#  2,
#  19,
#  19,
#  16,
#  38,
#  16,
#  45,
#  62,
#  16,
#  3,
#  49,
#  2,
#  45,
#  36,
#  62,
#  10,
#  37,
#  38,
#  37,
#  62,
#  55,
#  16,
#  38,
#  2,
#  3,
#  55,
#  2,
#  62,
#  3,
#  58,
#  49,
#  55,
#  10,
#  2,
#  3,
#  49,
#  50,
#  37,
#  50,
#  16,
#  38,
#  49,
#  50,
#  38,
#  6,
#  50,
#  6,
#  3,
#  16,
#  3,
#  49,
#  37,
#  45,
#  49,
#  34,
#  45,
#  3,
#  34,
#  50,
#  16,
#  38,
#  14,
#  2,
#  3,
#  16,
#  52,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  49,
#  52,
#  16,
#  55,
#  16,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  37,
#  26,
#  64,
#  6,
#  38,
#  2,
#  55,
#  10,
#  43,
#  36,
#  20,
#  37,
#  3,
#  16,
#  52,
#  49,
#  6,
#  45,
#  49,
#  37,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  18,
#  49,
#  17,
#  10,
#  2,
#  62,
#  10,
#  49,
#  2,
#  3,
#  49,
#  38,
#  16,
#  37,
#  26,
#  2,
#  59,
#  16,
#  52,
#  49,
#  34,
#  3,
#  2,
#  45,
#  64,
#  49,
#  6,
#  45,
#  26,
#  9,
#  49,
#  37,
#  49,
#  26,
#  37,
#  38,
#  64,
#  16,
#  49,
#  45,
#  34,
#  43,
#  20,
#  16,
#  38,
#  36,
#  6,
#  19,
#  49,
#  16,
#  37,
#  3,
#  2,
#  26,
#  9,
#  49,
#  6,
#  20,
#  55,
#  37,
#  2,
#  45,
#  16,
#  52,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  25,
#  19,
#  38,
#  16,
#  16,
#  49,
#  3,
#  37,
#  43,
#  50,
#  26,
#  16,
#  49,
#  52,
#  37,
#  55,
#  37,
#  58,
#  49,
#  55,
#  10,
#  16,
#  49,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  49,
#  2,
#  45,
#  62,
#  26,
#  34,
#  52,
#  16,
#  3,
#  49,
#  55,
#  17,
#  6,
#  49,
#  50,
#  37,
#  38,
#  55,
#  3,
#  56,
#  36,
#  2,
#  43,
#  37,
#  64,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  37,
#  45,
#  52,
#  49,
#  3,
#  34,
#  38,
#  19,
#  37,
#  62,
#  16,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  49,
#  37,
#  38,
#  16,
#  37,
#  49,
#  52,
#  16,
#  55,
#  16,
#  62,
#  55,
#  2,
#  6,
#  45,
#  58,
#  49,
#  55,
#  10,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  36,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  49,
#  2,
#  3,
#  49,
#  52,
#  16,
#  3,
#  2,
#  64,
#  45,
#  16,
#  52,
#  49,
#  55,
#  10,
#  38,
#  6,
#  34,
#  64,
#  10,
#  49,
#  37,
#  49,
#  19,
#  34,
#  26,
#  26,
#  9,
#  49,
#  62,
#  6,
#  45,
#  14,
#  6,
#  26,
#  34,
#  55,
#  2,
#  6,
#  45,
#  37,
#  26,
#  49,
#  37,
#  34,
#  55,
#  6,
#  16,
#  45,
#  62,
#  6,
#  52,
#  16,
#  38,
#  49,
#  17,
#  2,
#  55,
#  10,
#  49,
#  37,
#  36,
#  26,
#  2,
#  64,
#  10,
#  55,
#  17,
#  16,
#  2,
#  64,
#  10,
#  55,
#  49,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  34,
#  38,
#  16,
#  58,
#  49,
#  6,
#  45,
#  26,
#  9,
#  49,
#  37,
#  49,
#  3,
#  43,
#  37,
#  26,
#  26,
#  49,
#  45,
#  34,
#  43,
#  20,
#  16,
#  38,
#  49,
#  6,
#  19,
#  49,
#  45,
#  6,
#  38,
#  43,
#  37,
#  26,
#  49,
#  3,
#  37,
#  43,
#  50,
#  26,
#  16,
#  3,
#  49,
#  37,
#  38,
#  16,
#  49,
#  34,
#  3,
#  16,
#  52,
#  49,
#  19,
#  6,
#  38,
#  36,
#  55,
#  38,
#  37,
#  2,
#  45,
#  2,
#  45,
#  64,
#  49,
#  3,
#  6,
#  49,
#  55,
#  10,
#  37,
#  55,
#  49,
#  55,
#  10,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  49,
#  62,
#  37,
#  45,
#  49,
#  20,
#  16,
#  49,
#  37,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  25,
#  19,
#  38,
#  16,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  16,
#  52,
#  36,
#  2,
#  43,
#  37,
#  64,
#  16,
#  49,
#  2,
#  3,
#  49,
#  64,
#  16,
#  45,
#  16,
#  38,
#  37,
#  55,
#  16,
#  52,
#  58,
#  49,
#  37,
#  49,
#  19,
#  34,
#  45,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  62,
#  6,
#  43,
#  20,
#  2,
#  45,
#  2,
#  45,
#  64,
#  49,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  34,
#  38,
#  37,
#  26,
#  49,
#  26,
#  6,
#  3,
#  3,
#  49,
#  37,
#  45,
#  52,
#  49,
#  60,
#  47,
#  43,
#  37,
#  55,
#  10,
#  2,
#  55,
#  27,
#  26,
#  8,
#  29,
#  60,
#  49,
#  26,
#  6,
#  3,
#  3,
#  36,
#  2,
#  3,
#  49,
#  50,
#  38,
#  6,
#  50,
#  6,
#  3,
#  16,
#  52,
#  49,
#  37,
#  3,
#  49,
#  55,
#  10,
#  16,
#  49,
#  26,
#  6,
#  3,
#  3,
#  49,
#  19,
#  34,
#  45,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  6,
#  19,
#  49,
#  55,
#  10,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38,
#  34,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  45,
#  16,
#  55,
#  17,
#  6,
#  38,
#  61,
#  49,
#  55,
#  6,
#  49,
#  3,
#  6,
#  26,
#  14,
#  16,
#  49,
#  55,
#  10,
#  16,
#  36,
#  50,
#  38,
#  6,
#  20,
#  26,
#  16,
#  43,
#  49,
#  6,
#  19,
#  49,
#  50,
#  6,
#  6,
#  38,
#  49,
#  52,
#  16,
#  55,
#  16,
#  62,
#  55,
#  2,
#  6,
#  45,
#  49,
#  6,
#  19,
#  49,
#  2,
#  38,
#  38,
#  16,
#  64,
#  34,
#  26,
#  37,
#  38,
#  49,
#  55,
#  16,
#  28,
#  55,
#  34,
#  38,
#  16,
#  49,
#  3,
#  34,
#  38,
#  19,
#  37,
#  62,
#  16,
#  49,
#  52,
#  16,
#  19,
#  16,
#  62,
#  55,
#  3,
#  58,
#  49,
#  19,
#  34,
#  38,
#  55,
#  10,
#  16,
#  38,
#  18,
#  49,
#  55,
#  10,
#  16,
#  36,
#  38,
#  16,
#  3,
#  2,
#  52,
#  34,
#  37,
#  26,
#  49,
#  6,
#  19,
#  49,
#  55,
#  10,
#  16,
#  49,
#  38,
#  16,
#  62,
#  6,
#  45,
#  3,
#  55,
#  38]

# %% [markdown]
# ### Organizando y estructurando el dataset

# %%
# separaremos el dataset entre entrenamiento y validación.
# `p_val` será la proporción del corpus que se reservará para validación
# `num_val` es la cantidad de secuencias de tamaño `max_context_size` que se usará en validación
p_val = 0.1
num_val = int(np.ceil(len(tokenized_text)*p_val/max_context_size))

# %%
# separamos la porción de texto utilizada en entrenamiento de la de validación.
train_text = tokenized_text[:-num_val*max_context_size]
val_text = tokenized_text[-num_val*max_context_size:]

# %%
tokenized_sentences_val = [val_text[init*max_context_size:init*(max_context_size+1)] for init in range(num_val)]

# %%
tokenized_sentences_train = [train_text[init:init+max_context_size] for init in range(len(train_text)-max_context_size+1)]

# %%
X = np.array(tokenized_sentences_train[:-1])
y = np.array(tokenized_sentences_train[1:])

# %%
tokenized_sentences_train = [train_text[init:init+max_context_size] for init in range(len(train_text)-max_context_size+1)]

import numpy as np
from tensorflow.keras.preprocessing.sequence import pad_sequences

max_length = 100
train_text_indices = tokenized_text

input_sequences_train = []
target_sequences_train = []

for i in range(len(train_text_indices) - max_length):
    input_seq = train_text_indices[i : i + max_length]
    target_seq = train_text_indices[i + 1 : i + max_length + 1] # The next character at each step

    input_sequences_train.append(input_seq)
    target_sequences_train.append(target_seq)

X_train = np.array(input_sequences_train)
y_train = np.array(target_sequences_train)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of y_train: {y_train.shape}")
# Out:
# Shape of X_train: (120232, 100)
# Shape of y_train: (120232, 100)

# %% [markdown]
# Nótese que estamos estructurando el problema de aprendizaje como *many-to-many*:
#
# Entrada: secuencia de tokens [$x_0$, $x_1$, ..., $x_N$]
#
# Target: secuencia de tokens [$x_1$, $x_2$, ..., $x_{N+1}$]
#
# De manera que la red tiene que aprender que su salida deben ser los tokens desplazados en una posición y un nuevo token predicho (el N+1).
#
# La ventaja de estructurar el aprendizaje de esta manera es que para cada token de target se propaga una señal de gradiente por el grafo de cómputo recurrente, que es mejor que estructurar el problema como *many-to-one* en donde sólo una señal de gradiente se propaga.

# %% [markdown]
# En este punto tenemos en la variable `tokenized_sentences` los versos tokenizados. Vamos a quedarnos con un conjunto de validación que utilizaremos para medir la calidad de la generación de secuencias con la métrica de Perplejidad.

# %%
X.shape
# Out:
# (108132, 100)

# %%
X[0,:10]
# Out:
# array([37, 49, 26,  2, 64, 10, 55, 17, 16,  2])

# %%
y.shape
# Out:
# (108132, 100)

# %%
y[0,:10]
# Out:
# array([49, 26,  2, 64, 10, 55, 17, 16,  2, 64])

# %%
vocab_size = len(chars_vocab)

# %% [markdown]
# # Definiendo los modelos
#
# Pruebo los modelos sugeridos, SimpleRNN, LSTM y GRU

# %%
from keras.layers import Input, TimeDistributed, CategoryEncoding, SimpleRNN, Dense
from keras.models import Model, Sequential

# %% [markdown]
# El modelo que se propone como ejemplo consume los índices de los tokens y los transforma en vectores OHE (en este caso no entrenamos una capa de embedding para caracteres). Esa transformación se logra combinando las capas `CategoryEncoding` que transforma a índices a vectores OHE y `TimeDistributed` que aplica la capa a lo largo de la dimensión "temporal" de la secuencia.

# %%
model_SimpleRNN = Sequential()

model_SimpleRNN.add(TimeDistributed(CategoryEncoding(num_tokens=vocab_size, output_mode = "one_hot"),input_shape=(None,1)))
model_SimpleRNN.add(SimpleRNN(200, return_sequences=True, dropout=0.1, recurrent_dropout=0.1 ))
model_SimpleRNN.add(Dense(vocab_size, activation='softmax'))
model_SimpleRNN.compile(loss='sparse_categorical_crossentropy', optimizer='rmsprop')

model_SimpleRNN.summary()
# Out:
# /home/juan/anaconda3/envs/CEIA/lib/python3.12/site-packages/keras/src/layers/core/wrapper.py:27: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# I0000 00:00:1745777138.836089   31683 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 6103 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.9
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ time_distributed                │ (None, None, 65)       │             0 │
# │ (TimeDistributed)               │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ simple_rnn (SimpleRNN)          │ (None, None, 200)      │        53,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, None, 65)       │        13,065 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 66,265 (258.85 KB)
#  Trainable params: 66,265 (258.85 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# En el modelo LSTM en vez de aplicar OHE se agrega una capa de embedding a la entrada.

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dropout, Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy

model_lstm = Sequential()

# Embedding:
# input_seq_len = max_context_size --> longitud máxima de la secuencia de entrada
# input_dim = vocab_size + 1 --> tamaño del vocabulario (palabras distintas + token para fuera de vocabulario)
# output_dim = 50 --> dimensión del espacio de embedding
model_lstm.add(Embedding(input_dim=vocab_size + 1,
                    output_dim=50,
                    input_shape=(max_context_size,)))

model_lstm.add(LSTM(64, return_sequences=True))
model_lstm.add(Dropout(0.2))
model_lstm.add(LSTM(64,return_sequences=True)) # La última capa LSTM no lleva return_sequences
model_lstm.add(Dense(32, activation='relu'))

# Predicción de clasificación con softmax
# La salida vuelve al espacio de vocab_size + 1 palabras posibles
model_lstm.add(Dense(vocab_size + 1, activation='softmax'))

# Clasificación multiple categórica --> loss = SparseCategoricalCrossentropy
model_lstm.compile(loss=SparseCategoricalCrossentropy(), optimizer='rmsprop', metrics=['accuracy'])

model_lstm.summary()
# Out:
# /home/juan/anaconda3/envs/CEIA/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ (None, 100, 50)        │         3,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 100, 64)        │        29,440 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 100, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 100, 64)        │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 100, 32)        │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100, 66)        │         2,178 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 70,022 (273.52 KB)
#  Trainable params: 70,022 (273.52 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Por ultimo probamos el modelo GRU

# %%
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, GRU, Dropout, Dense
from tensorflow.keras.losses import SparseCategoricalCrossentropy


def crear_modelo_gru(vocab_size, embedding_dim, rnn_units, dropout_rate, sequence_length):
    model = Sequential([
        Embedding(input_dim=vocab_size + 1, # 
                  output_dim=embedding_dim,
                  input_shape=(sequence_length,)),
        GRU(rnn_units, return_sequences=True, dropout=dropout_rate, recurrent_dropout=dropout_rate),
        GRU(rnn_units, return_sequences=True, dropout=dropout_rate, recurrent_dropout=dropout_rate),
        Dense(vocab_size + 1, activation='softmax')
    ])
    return model

embedding_dim = 64
rnn_units = 64
dropout_rate = 0.2
sequence_length = max_context_size

model_gru = crear_modelo_gru(vocab_size, embedding_dim, rnn_units, dropout_rate, sequence_length)

model_gru.compile(loss=SparseCategoricalCrossentropy(), optimizer='rmsprop', metrics=['accuracy'])

model_gru.summary()
# Out:
# /home/juan/anaconda3/envs/CEIA/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_1 (Embedding)         │ (None, 100, 64)        │         4,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru (GRU)                       │ (None, 100, 64)        │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ gru_1 (GRU)                     │ (None, 100, 64)        │        24,960 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 100, 66)        │         4,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 58,434 (228.26 KB)
#  Trainable params: 58,434 (228.26 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Definir el modelo

# %% [markdown]
# Dado que por el momento no hay implementaciones adecuadas de la perplejidad que puedan operar en tiempo de entrenamiento, armaremos un Callback *ad-hoc* que la calcule en cada epoch.
#
# **Nota**: un Callback es una rutina gatillada por algún evento, son muy útiles para relevar datos en diferentes momentos del desarrollo del modelo. En este caso queremos hacer un cálculo cada vez que termina una epoch de entrenamiento.

# %%
class PplCallback(keras.callbacks.Callback):

    '''
    Este callback es una solución ad-hoc para calcular al final de cada epoch de
    entrenamiento la métrica de Perplejidad sobre un conjunto de datos de validación.
    La perplejidad es una métrica cuantitativa para evaluar la calidad de la generación de secuencias.
    Además implementa la finalización del entrenamiento (Early Stopping)
    si la perplejidad no mejora después de `patience` epochs.
    '''

    def __init__(self, val_data, history_ppl,model_name='my_model',patience=3):
      # El callback lo inicializamos con secuencias de validación sobre las cuales
      # mediremos la perplejidad
      self.val_data = val_data
      self.model_name = model_name
      self.target = []
      self.padded = []
      self.history_ppl = history_ppl
      count = 0
      self.info = []
      self.min_score = np.inf
      self.patience_counter = 0
      self.patience = patience

      # nos movemos en todas las secuencias de los datos de validación
      for seq in self.val_data:

        len_seq = len(seq)
        # armamos todas las subsecuencias
        subseq = [seq[:i] for i in range(1,len_seq)]
        self.target.extend([seq[i] for i in range(1,len_seq)])

        if len(subseq)!=0:

          self.padded.append(pad_sequences(subseq, maxlen=max_context_size, padding='pre'))

          self.info.append((count,count+len_seq))
          count += len_seq

      self.padded = np.vstack(self.padded)
      print("padded shape:", self.padded.shape)
      print("total sequences:", len(self.padded))
      print("max sequence length:", self.padded.shape[1])


    def on_epoch_end(self, epoch, logs=None):

        # en `scores` iremos guardando la perplejidad de cada secuencia
        scores = []

        predictions = self.model.predict(self.padded,verbose=0)

        # para cada secuencia de validación
        for start,end in self.info:

          # en `probs` iremos guardando las probabilidades de los términos target
          probs = [predictions[idx_seq,-1,idx_vocab] for idx_seq, idx_vocab in zip(range(start,end),self.target[start:end])]

          # calculamos la perplejidad por medio de logaritmos
          scores.append(np.exp(-np.sum(np.log(probs))/(end-start)))

        # promediamos todos los scores e imprimimos el valor promedio
        current_score = np.mean(scores)
        self.history_ppl.append(current_score)
        print(f'\n mean perplexity: {current_score} \n')

        # chequeamos si tenemos que detener el entrenamiento
        if current_score < self.min_score:
          self.min_score = current_score
          self.model.save(self.model_name+'.keras')
          print("Saved new model!")
          self.patience_counter = 0
        else:
          self.patience_counter += 1
          if self.patience_counter == self.patience:
            print("Stopping training...")
            self.model.stop_training = True

# %% [markdown]
# ### Entrenamiento

# %%
y_train.shape
# Out:
# (120232, 100)

# %%
history_ppl_lstm = []
hist_lstm = model_lstm.fit(X_train, y_train, epochs=20,callbacks=[PplCallback(tokenized_sentences_val,history_ppl_lstm,model_name='model_lstm')],  batch_size=256)
# Out:
# padded shape: (7120, 100)
# total sequences: 7120
# max sequence length: 100
# Epoch 1/20
# I0000 00:00:1745777141.283334   31821 cuda_dnn.cc:529] Loaded cuDNN version 90300
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1157 - loss: 3.2225
#  mean perplexity: 21.910817640179395
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 8s 12ms/step - accuracy: 0.1157 - loss: 3.2223
# Epoch 2/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.1466 - loss: 2.9772
#  mean perplexity: 16.511060656594353
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.1467 - loss: 2.9768
# Epoch 3/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2381 - loss: 2.6519
#  mean perplexity: 13.431426354517487
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - accuracy: 0.2382 - loss: 2.6516
# Epoch 4/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2903 - loss: 2.4652
#  mean perplexity: 11.460540393231954
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.2904 - loss: 2.4651
# Epoch 5/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3316 - loss: 2.3183
#  mean perplexity: 10.264064021044915
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.3317 - loss: 2.3182
# Epoch 6/20
# 465/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3566 - loss: 2.2149
#  mean perplexity: 9.451266087711051
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - accuracy: 0.3567 - loss: 2.2146
# Epoch 7/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3846 - loss: 2.1214
#  mean perplexity: 8.9682312657559
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.3846 - loss: 2.1214
# Epoch 8/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4046 - loss: 2.0425
#  mean perplexity: 8.726478011164048
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 7s 15ms/step - accuracy: 0.4046 - loss: 2.0425
# Epoch 9/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4211 - loss: 1.9768
#  mean perplexity: 8.192295553541591
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.4211 - loss: 1.9766
# Epoch 10/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.4376 - loss: 1.9184
#  mean perplexity: 7.834637659611655
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - accuracy: 0.4376 - loss: 1.9183
# Epoch 11/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.4523 - loss: 1.8693
#  mean perplexity: 7.620595183097282
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 10s 22ms/step - accuracy: 0.4523 - loss: 1.8692
# Epoch 12/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4651 - loss: 1.8271
#  mean perplexity: 7.834964271480978
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.4651 - loss: 1.8270
# Epoch 13/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4769 - loss: 1.7890
#  mean perplexity: 7.867931269322864
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.4769 - loss: 1.7889
# Epoch 14/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.4865 - loss: 1.7567
#  mean perplexity: 7.930788327871806
#
# Stopping training...
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 23s 49ms/step - accuracy: 0.4865 - loss: 1.7566

# %%
history_gru = []
hist_gru = model_gru.fit(X_train, y_train, epochs=20, callbacks=[PplCallback(tokenized_sentences_val,history_gru,model_name='model_GRU')], batch_size=256)
# Out:
# padded shape: (7120, 100)
# total sequences: 7120
# max sequence length: 100
# Epoch 1/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 628ms/step - accuracy: 0.1746 - loss: 3.0035
#  mean perplexity: 10.755094255091343
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 326s 650ms/step - accuracy: 0.1747 - loss: 3.0028
# Epoch 2/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step - accuracy: 0.3573 - loss: 2.2138
#  mean perplexity: 8.305351878067912
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 159s 340ms/step - accuracy: 0.3574 - loss: 2.2137
# Epoch 3/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.4240 - loss: 1.9755
#  mean perplexity: 7.193253187944164
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 181s 386ms/step - accuracy: 0.4240 - loss: 1.9754
# Epoch 4/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step - accuracy: 0.4592 - loss: 1.8457
#  mean perplexity: 6.677099927938126
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 210s 447ms/step - accuracy: 0.4592 - loss: 1.8457
# Epoch 5/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 422ms/step - accuracy: 0.4800 - loss: 1.7705
#  mean perplexity: 6.308174884826734
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 215s 458ms/step - accuracy: 0.4800 - loss: 1.7704
# Epoch 6/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 424ms/step - accuracy: 0.4937 - loss: 1.7210
#  mean perplexity: 6.0788736439559745
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 216s 459ms/step - accuracy: 0.4937 - loss: 1.7210
# Epoch 7/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 435ms/step - accuracy: 0.5021 - loss: 1.6895
#  mean perplexity: 5.967076243316659
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 222s 473ms/step - accuracy: 0.5022 - loss: 1.6895
# Epoch 8/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 385ms/step - accuracy: 0.5084 - loss: 1.6644
#  mean perplexity: 5.847613885694456
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 198s 420ms/step - accuracy: 0.5084 - loss: 1.6644
# Epoch 9/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.5135 - loss: 1.6442
#  mean perplexity: 5.85271664588872
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 186s 396ms/step - accuracy: 0.5135 - loss: 1.6442
# Epoch 10/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.5172 - loss: 1.6295
#  mean perplexity: 5.725547391782457
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 158s 335ms/step - accuracy: 0.5172 - loss: 1.6294
# Epoch 11/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 240ms/step - accuracy: 0.5206 - loss: 1.6151
#  mean perplexity: 5.630141565025271
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 122s 260ms/step - accuracy: 0.5206 - loss: 1.6151
# Epoch 12/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 234ms/step - accuracy: 0.5233 - loss: 1.6050
#  mean perplexity: 5.599353808713414
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 119s 253ms/step - accuracy: 0.5233 - loss: 1.6050
# Epoch 13/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - accuracy: 0.5251 - loss: 1.5975
#  mean perplexity: 5.573332987615438
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 104s 222ms/step - accuracy: 0.5251 - loss: 1.5974
# Epoch 14/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5272 - loss: 1.5882
#  mean perplexity: 5.597692891001528
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 86s 183ms/step - accuracy: 0.5272 - loss: 1.5882
# Epoch 15/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - accuracy: 0.5290 - loss: 1.5810
#  mean perplexity: 5.549004364882451
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 106s 225ms/step - accuracy: 0.5290 - loss: 1.5810
# Epoch 16/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 242ms/step - accuracy: 0.5306 - loss: 1.5753
#  mean perplexity: 5.56793374500942
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 123s 261ms/step - accuracy: 0.5306 - loss: 1.5753
# Epoch 17/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 250ms/step - accuracy: 0.5319 - loss: 1.5706
#  mean perplexity: 5.587135996187725
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 128s 273ms/step - accuracy: 0.5319 - loss: 1.5706
# Epoch 18/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step - accuracy: 0.5325 - loss: 1.5667
#  mean perplexity: 5.608278373327667
#
# Stopping training...
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 142s 303ms/step - accuracy: 0.5325 - loss: 1.5667

# %%
# fiteamos, nótese el agregado del callback con su inicialización. El batch_size lo podemos seleccionar a mano
# en general, lo mejor es escoger el batch más grande posible que minimice el tiempo de cada época.
# En la variable `history_ppl` se guardarán los valores de perplejidad para cada época.
history_ppl = []
hist = model_SimpleRNN.fit(X_train, y_train, epochs=20, callbacks=[PplCallback(tokenized_sentences_val,history_ppl,model_name='model_SimpleRNN')], batch_size=256)
# Out:
# padded shape: (7120, 100)
# total sequences: 7120
# max sequence length: 100
# Epoch 1/20
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1745780285.452346   31796 service.cc:152] XLA service 0x7b8964006de0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1745780285.452371   31796 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Laptop GPU, Compute Capability 8.9
# 2025-04-27 15:58:05.654450: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-04-27 15:58:05.677125: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-04-27 15:58:07.202795: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 128 bytes spill stores, 128 bytes spill loads
#
# 2025-04-27 15:58:07.370723: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 92 bytes spill stores, 92 bytes spill loads
#
# 2025-04-27 15:58:07.443773: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-04-27 15:58:07.445801: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33_0', 872 bytes spill stores, 872 bytes spill loads
#
# 2025-04-27 15:58:07.451570: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 584 bytes spill stores, 564 bytes spill loads
#
# 2025-04-27 15:58:07.516134: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 676 bytes spill stores, 520 bytes spill loads
#
# 2025-04-27 15:58:07.619130: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 360 bytes spill stores, 360 bytes spill loads
#
# 2025-04-27 15:58:07.627211: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 532 bytes spill stores, 532 bytes spill loads
#
# 2025-04-27 15:58:07.630739: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 468 bytes spill stores, 468 bytes spill loads
#
# 2025-04-27 15:58:07.711990: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 312 bytes spill stores, 312 bytes spill loads
#
# 2025-04-27 15:58:07.734432: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 156 bytes spill stores, 156 bytes spill loads
#
# 2025-04-27 15:58:07.854118: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 188 bytes spill stores, 188 bytes spill loads
#
# 2025-04-27 15:58:07.884219: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 4 bytes spill stores, 4 bytes spill loads
#
# 2025-04-27 15:58:08.273099: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 244 bytes spill stores, 244 bytes spill loads
#
# 2025-04-27 15:58:08.379010: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-04-27 15:58:08.445371: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 804 bytes spill stores, 648 bytes spill loads
#
# 2025-04-27 15:58:08.545848: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-04-27 15:58:08.702422: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-04-27 15:58:08.840039: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 716 bytes spill stores, 720 bytes spill loads
#
# 2025-04-27 15:58:09.124468: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 540 bytes spill stores, 540 bytes spill loads
#
# 2025-04-27 15:58:09.156752: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 120 bytes spill stores, 120 bytes spill loads
#
# 2025-04-27 15:58:09.251044: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 1328 bytes spill stores, 1032 bytes spill loads
#
# 2025-04-27 15:58:09.338293: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 1856 bytes spill stores, 1388 bytes spill loads
#
# 2025-04-27 15:58:09.378757: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 8508 bytes spill stores, 8576 bytes spill loads
#
# 2025-04-27 15:58:09.507989: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 304 bytes spill stores, 304 bytes spill loads
#
# 2025-04-27 15:58:09.855578: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 844 bytes spill stores, 844 bytes spill loads
#
# 2025-04-27 15:58:10.037506: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-04-27 15:58:10.103699: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 540 bytes spill stores, 540 bytes spill loads
#
# 2025-04-27 15:58:10.189060: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 648 bytes spill stores, 648 bytes spill loads
#
# 2025-04-27 15:58:11.146594: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 1836 bytes spill stores, 1876 bytes spill loads
#  11/470 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step - loss: 3.7554
# 2025-04-27 15:58:16.033706: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'fusion_144', 668 bytes spill stores, 668 bytes spill loads
# ptxas warning : Registers are spilled to local memory in function 'fusion_146', 536 bytes spill stores, 536 bytes spill loads
#
# I0000 00:00:1745780296.074320   31796 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.7877
# 2025-04-27 15:58:19.975558: W tensorflow/compiler/tf2xla/kernels/assert_op.cc:39] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 2025-04-27 15:58:21.639071: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 816 bytes spill stores, 656 bytes spill loads
#
# 2025-04-27 15:58:21.701519: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 364 bytes spill stores, 364 bytes spill loads
#
# 2025-04-27 15:58:21.768064: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 688 bytes spill stores, 528 bytes spill loads
#
# 2025-04-27 15:58:21.822161: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 160 bytes spill stores, 160 bytes spill loads
#
# 2025-04-27 15:58:21.860259: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 564 bytes spill stores, 544 bytes spill loads
#
# 2025-04-27 15:58:21.928897: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 116 bytes spill stores, 116 bytes spill loads
#
# 2025-04-27 15:58:21.951555: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 376 bytes spill stores, 376 bytes spill loads
#
# 2025-04-27 15:58:22.013205: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 444 bytes spill stores, 444 bytes spill loads
#
# 2025-04-27 15:58:22.080518: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 188 bytes spill stores, 188 bytes spill loads
#
# 2025-04-27 15:58:22.102403: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 168 bytes spill stores, 168 bytes spill loads
#
# 2025-04-27 15:58:22.252620: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 8596 bytes spill stores, 8756 bytes spill loads
#
# 2025-04-27 15:58:22.279594: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33_0', 980 bytes spill stores, 980 bytes spill loads
#
# 2025-04-27 15:58:22.304993: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_33', 608 bytes spill stores, 588 bytes spill loads
#
# 2025-04-27 15:58:22.432664: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 1364 bytes spill stores, 1048 bytes spill loads
#
# 2025-04-27 15:58:22.766329: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 8496 bytes spill stores, 8540 bytes spill loads
#
# 2025-04-27 15:58:23.055414: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 540 bytes spill stores, 540 bytes spill loads
#
# 2025-04-27 15:58:23.239659: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 28 bytes spill stores, 28 bytes spill loads
#
# 2025-04-27 15:58:23.658711: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 132 bytes spill stores, 132 bytes spill loads
#
# 2025-04-27 15:58:23.663574: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 76 bytes spill stores, 76 bytes spill loads
#
# 2025-04-27 15:58:23.681960: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 308 bytes spill stores, 308 bytes spill loads
#
# 2025-04-27 15:58:23.720788: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 540 bytes spill stores, 540 bytes spill loads
#
# 2025-04-27 15:58:23.808150: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 1836 bytes spill stores, 1876 bytes spill loads
#
# 2025-04-27 15:58:23.885414: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-04-27 15:58:23.907178: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 12 bytes spill stores, 12 bytes spill loads
#
# 2025-04-27 15:58:23.993854: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 64 bytes spill stores, 64 bytes spill loads
#
# 2025-04-27 15:58:24.072021: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 120 bytes spill stores, 120 bytes spill loads
#
# 2025-04-27 15:58:24.285318: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 504 bytes spill stores, 504 bytes spill loads
#
# 2025-04-27 15:58:24.440912: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 648 bytes spill stores, 648 bytes spill loads
#
# 2025-04-27 15:58:24.482433: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1', 732 bytes spill stores, 736 bytes spill loads
#
# 2025-04-27 15:58:24.685855: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_3482', 844 bytes spill stores, 844 bytes spill loads
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 2.7860
#  mean perplexity: 9.729307828827992
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 31s 38ms/step - loss: 2.7855
# Epoch 2/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.2020
#  mean perplexity: 7.460741329029476
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 2.2017
# Epoch 3/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 2.0001
#  mean perplexity: 6.343608965904142
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 2.0000
# Epoch 4/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.8759
#  mean perplexity: 5.845939210292476
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step - loss: 1.8758
# Epoch 5/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7981
#  mean perplexity: 5.596334440921889
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - loss: 1.7980
# Epoch 6/20
# 466/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7450
#  mean perplexity: 5.219287078678003
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step - loss: 1.7449
# Epoch 7/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.7112
#  mean perplexity: 5.079467748445279
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - loss: 1.7112
# Epoch 8/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6814
#  mean perplexity: 4.98222975875664
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6814
# Epoch 9/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6632
#  mean perplexity: 4.806042208110839
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6632
# Epoch 10/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6471
#  mean perplexity: 4.927235441852796
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6471
# Epoch 11/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6314
#  mean perplexity: 4.800578240715377
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6313
# Epoch 12/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6200
#  mean perplexity: 4.762561190454664
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6200
# Epoch 13/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6106
#  mean perplexity: 4.740062607337548
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6106
# Epoch 14/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.6027
#  mean perplexity: 4.653144761276159
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.6027
# Epoch 15/20
# 469/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5947
#  mean perplexity: 4.631337807053935
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.5947
# Epoch 16/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5894
#  mean perplexity: 4.6667660545742695
#
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.5894
# Epoch 17/20
# 467/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5803
#  mean perplexity: 4.580218101498923
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 1.5803
# Epoch 18/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5778
#  mean perplexity: 4.5130143736436095
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 20ms/step - loss: 1.5778
# Epoch 19/20
# 468/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5709
#  mean perplexity: 4.5078946581551875
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.5709
# Epoch 20/20
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 1.5665
#  mean perplexity: 4.480527403133157
#
# Saved new model!
# 470/470 ━━━━━━━━━━━━━━━━━━━━ 9s 19ms/step - loss: 1.5665

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Entrenamiento
epoch_count = range(1, len(history_ppl_lstm) + 1)
sns.lineplot(x=epoch_count,  y=history_ppl_lstm,label='lstm',legend=True)
epoch_count = range(1, len(history_ppl) + 1)
sns.lineplot(x=epoch_count,  y=history_ppl,label='simpleRNN',legend=True)
epoch_count = range(1, len(history_gru) + 1)

sns.lineplot(x=epoch_count,  y=history_gru,label='GRU',legend=True)

plt.show()
plt.savefig('perplexity.png')

# %%
# Cargamos el mejor modelo guardado del entrenamiento para hacer inferencia
model_simpleRNN = keras.models.load_model('model_SimpleRNN.keras')
model_gru = keras.models.load_model('model_GRU.keras')
model_lstm = keras.models.load_model('model_lstm.keras')

# %% [markdown]
# ### Predicción del próximo caracter

# %%
# Se puede usar gradio para probar el modelo
# Gradio es una herramienta muy útil para crear interfaces para ensayar modelos
# https://gradio.app/

# !pip install -q gradio

# %%
import gradio as gr

def model_response(human_text):

    # Encodeamos
    encoded = [char2idx[ch] for ch in human_text.lower() ]
    # Si tienen distinto largo
    encoded = pad_sequences([encoded], maxlen=max_context_size, padding='pre')

    # Predicción softmax
    y_hat = np.argmax(model.predict(encoded)[0,-1,:])


    # Debemos buscar en el vocabulario el caracter
    # que corresopnde al indice (y_hat) predicho por le modelo
    out_word = ''
    out_word = idx2char[y_hat]

    # Agrego la palabra a la frase predicha
    return human_text + out_word

iface = gr.Interface(
    fn=model_response,
    inputs=["textbox"],
    outputs="text")

# iface.launch(debug=True)

# %% [markdown]
# ### Generación de secuencias

# %%
def generate_seq(model, seed_text, max_length, n_words):
    """
        Exec model sequence prediction

        Args:
            model (keras): modelo entrenado
            seed_text (string): texto de entrada (input_seq)
            max_length (int): máxima longitud de la sequencia de entrada
            n_words (int): números de caracteres a agregar a la sequencia de entrada
        returns:
            output_text (string): sentencia con las "n_words" agregadas
    """
    output_text = seed_text
	# generate a fixed number of words
    for _ in range(n_words):
		# Encodeamos
        encoded = [char2idx[ch] for ch in output_text.lower() ]
		# Si tienen distinto largo
        encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

		# Predicción softmax
        y_hat = np.argmax(model.predict(encoded,verbose=0)[0,-1,:])
		# Vamos concatenando las predicciones
        out_word = ''

        out_word = idx2char[y_hat]

		# Agrego las palabras a la frase predicha
        output_text += out_word
    return output_text

# %%
input_text='modern artificial'

generate_seq(model_lstm, input_text, max_length=max_context_size, n_words=100)
# Out:
# 'modern artificial and the the the the the the the the the the the the the the the the the the the the the the the the'

# %%
generate_seq(model_gru, input_text, max_length=max_context_size, n_words=100)
# Out:
# 'modern artificial and the context in the and the context in the and the context in the and the context in the and the'

# %%
generate_seq(model_simpleRNN, input_text, max_length=max_context_size, n_words=100)
# Out:
# 'modern artificial relations of the art models for the construction of the art models for the construction of the art '

# %% [markdown]
# ###  Beam search y muestreo aleatorio

# %%
# funcionalidades para hacer encoding y decoding

def encode(text,max_length=max_context_size):

    encoded = [char2idx[ch] for ch in text]
    encoded = pad_sequences([encoded], maxlen=max_length, padding='pre')

    return encoded

def decode(seq):
    return ''.join([idx2char[ch] for ch in seq])

# %%
from scipy.special import softmax

# función que selecciona candidatos para el beam search
def select_candidates(pred,num_beams,vocab_size,history_probs,history_tokens,temp,mode):

  # colectar todas las probabilidades para la siguiente búsqueda
  pred_large = []

  for idx,pp in enumerate(pred):
    pred_large.extend(np.log(pp+1E-10)+history_probs[idx])

  pred_large = np.array(pred_large)

  # criterio de selección
  if mode == 'det':
    idx_select = np.argsort(pred_large)[::-1][:num_beams] # beam search determinista
  elif mode == 'sto':
    idx_select = np.random.choice(np.arange(pred_large.shape[0]), num_beams, p=softmax(pred_large/temp)) # beam search con muestreo aleatorio
  else:
    raise ValueError(f'Wrong selection mode. {mode} was given. det and sto are supported.')

  # traducir a índices de token en el vocabulario
  new_history_tokens = np.concatenate((np.array(history_tokens)[idx_select//vocab_size],
                        np.array([idx_select%vocab_size]).T),
                      axis=1)

  # devolver el producto de las probabilidades (log) y la secuencia de tokens seleccionados
  return pred_large[idx_select.astype(int)], new_history_tokens.astype(int)


def beam_search(model,num_beams,num_words,input,temp=1,mode='det'):

    # first iteration

    # encode
    encoded = encode(input)

    # first prediction
    y_hat = model.predict(encoded,verbose=0)[0,-1,:]

    # get vocabulary size
    vocab_size = y_hat.shape[0]

    # initialize history
    history_probs = [0]*num_beams
    history_tokens = [encoded[0]]*num_beams

    # select num_beams candidates
    history_probs, history_tokens = select_candidates([y_hat],
                                        num_beams,
                                        vocab_size,
                                        history_probs,
                                        history_tokens,
                                        temp,
                                        mode)

    # beam search loop
    for i in range(num_words-1):

      preds = []

      for hist in history_tokens:

        # actualizar secuencia de tokens
        input_update = np.array([hist[i+1:]]).copy()

        # predicción
        y_hat = model.predict(input_update,verbose=0)[0,-1,:]

        preds.append(y_hat)

      history_probs, history_tokens = select_candidates(preds,
                                                        num_beams,
                                                        vocab_size,
                                                        history_probs,
                                                        history_tokens,
                                                        temp,
                                                        mode)

    return history_tokens[:,-(len(input)+num_words):]

# %% [markdown]
# ### Predicciones con beamsearch deterministico

# %%
# predicción con beam search
salidas = beam_search(model_lstm,num_beams=5,num_words=50,input="modern",mode='det')
decode(salidas[0])
# Out:
# 'moderning the proposed of the proposed the proposed the '

# %%
# predicción con beam search
salidas = beam_search(model_gru,num_beams=5,num_words=50,input="modern",mode='det')
decode(salidas[0])
# Out:
# 'moderness of the construction analysis of the problems. '

# %%
# predicción con beam search
salidas = beam_search(model_simpleRNN,num_beams=5,num_words=50,input="modern",mode='det')
decode(salidas[0])
# Out:
# 'modernative learning in this paper, we proposed methods '

# %% [markdown]
# ### Predicciones con beamsearch estocastico
# Ahora podemos jugar un poco con la temperatura

# %% [markdown]
# #### Temperatura baja

# %%
# predicción con beam search
salidas = beam_search(model_lstm,num_beams=5,num_words=50,input="modern",temp=2,mode='sto')
decode(salidas[0])
# Out:
# 'modernet\ndatal ope semobceral firmatizity of\ntractic ems'

# %%
# predicción con beam search
salidas = beam_search(model_gru,num_beams=5,num_words=50,input="modern",temp=2,mode='sto')
decode(salidas[0])# predicción con beam search
# Out:
# 'modernes over of poginations seured the representilatiok'

# %%
salidas = beam_search(model_simpleRNN,num_beams=5,num_words=50,input="modern",temp=2,mode='sto')
decode(salidas[0])
# Out:
# 'moderngnew\npeomiation algorithm reallig the bersural\nlav'

# %% [markdown]
# #### Temperatura alta

# %%
# predicción con beam search
salidas = beam_search(model_lstm,num_beams=5,num_words=50,input="modern",temp=10,mode='det')
decode(salidas[0])
# Out:
# 'moderning the proposed of the proposed the proposed the '

# %%
# predicción con beam search
salidas = beam_search(model_gru,num_beams=5,num_words=50,input="modern",temp=10,mode='det')
decode(salidas[0])
# Out:
# 'moderness of the construction analysis of the problems. '

# %%
salidas = beam_search(model_simpleRNN,num_beams=5,num_words=50,input="modern",temp=10,mode='det')
decode(salidas[0])
# Out:
# 'modernative learning in this paper, we proposed methods '

# %% [markdown]
# # Conclusiones
#
# La evolucion de la estimacion de perplejidad con el callback provisto parece bastante razonable en todos los casos, se ve que los modelos aprenden.
#
# Los modelos entrenados infieren en su mayoria palabras reales en el modo de inferencia 'deterministico' o usando softmax, pero no logran producir muchos caracteres.
#
# Esto en principio yo se lo atribuiria a los datos, ya que hay muchos terminos que se repiten en los abstracts de papers y por lo tanto el dataset esta bastante sesgado hacia esos terminos o expresiones, comose puede apreciar en los distintos resultados que pude obtener.
#
# Sin embargo podria probar tambien agrandando el contexto utilizado en entrenamiento (100 caracteres) o bien las epocas de entrenamiento (50 o 100).  Quizas tambien agregando mas neuronas en las capas recurrentes se puedan obtener mejores resultados.
#
# Por ultimo en el experimento de la inferencia utilizando beams earch estocastico, pude comprobar que la temperatura influye en la diversidad de las predicciones. Incluso generando secuencias más lógicas / interesantes que con el metodo deterministico.
